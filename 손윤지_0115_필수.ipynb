# %% [markdown]
# <a href="https://colab.research.google.com/github/YunjiSon/BDAA/blob/main/%EC%86%90%EC%9C%A4%EC%A7%80_0115_%ED%95%84%EC%88%98.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install -U finance-datareader
import FinanceDataReader as fdr
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
df_krx = fdr.StockListing('KRX')

# %%
df_krx
# Out:
#         Code        ISU_CD      Name Market   Dept   Close ChangeCode  \
# 0     005930  KR7005930003      삼성전자  KOSPI          64600          1
# 1     373220  KR7373220003  LG에너지솔루션  KOSPI         506000          2
# 2     000660  KR7000660001    SK하이닉스  KOSPI          91500          2
# 3     207940  KR7207940008  삼성바이오로직스  KOSPI         809000          1
# 4     051910  KR7051910008      LG화학  KOSPI         685000          3
# ...      ...           ...       ...    ...    ...     ...        ...
# 2689  308700  KR7308700004       테크엔  KONEX  일반기업부     577          1
# 2690  215050  KR7215050006   비엔디생활건강  KONEX  일반기업부     912          0
# 2691  267810  KR7267810000        앙츠  KONEX  일반기업부    1058          4
# 2692  267060  KR7267060002     명진홀딩스  KONEX  일반기업부     181          0
# 2693  322190  KR7322190000        베른  KONEX  일반기업부     108          1
#
#       Changes  ChagesRatio    Open    High     Low    Volume         Amount  \
# ...

# %%
df_krx.iloc[0]
# Out:
# Code                    005930
# ISU_CD            KR7005930003
# Name                      삼성전자
# Market                   KOSPI
# Dept
# Close                    64600
# ChangeCode                   1
# Changes                    700
# ChagesRatio                1.1
# Open                     64400
# High                     65000
# Low                      63900
# Volume                18760182
# Amount           1212764792491
# Marcap         385647952730000
# Stocks              5969782550
# MarketId                   STK
# Name: 0, dtype: object

# %% [markdown]
# 반도체 기업이라는 측면에서 SK 하이닉스와 비교

# %%
df_krx.iloc[2]
# Out:
# Code                   000660
# ISU_CD           KR7000660001
# Name                   SK하이닉스
# Market                  KOSPI
# Dept
# Close                   91500
# ChangeCode                  2
# Changes                  -800
# ChagesRatio             -0.87
# Open                    91300
# High                    92800
# Low                     90300
# Volume                2553811
# Amount           234318676392
# Marcap         66612216397500
# Stocks              728002365
# MarketId                  STK
# Name: 2, dtype: object

# %%
df_ss = fdr.DataReader('005930', '2023')
df_ss
# Out:
#              Open   High    Low  Close    Volume    Change
# Date
# 2023-01-02  55500  56100  55200  55500  10031448  0.003617
# 2023-01-03  55400  56000  54500  55400  13547030 -0.001802
# 2023-01-04  55700  58000  55600  57800  20188071  0.043321
# 2023-01-05  58200  58800  57600  58200  15682826  0.006920
# 2023-01-06  58300  59400  57900  59000  17334989  0.013746
# 2023-01-09  59700  60700  59600  60700  18640107  0.028814
# 2023-01-10  60200  61100  59900  60400  14859797 -0.004942
# 2023-01-11  61000  61200  60300  60500  12310751  0.001656
# 2023-01-12  61100  61200  59900  60500  16102561  0.000000
# 2023-01-13  60500  61200  60400  60800  12510328  0.004959
# 2023-01-16  61300  61600  60800  61100  10039972  0.004934
# 2023-01-17  61200  61500  60600  61000   9831456 -0.001637
# 2023-01-18  60700  61000  59900  60400  11584041 -0.009836
# 2023-01-19  60500  61500  60400  61500  12808490  0.018212
# 2023-01-20  62100  62300  61100  61800   9646327  0.004878
# ...

# %%
df_sh = fdr.DataReader('000660', '2023')
df_sh
# Out:
#              Open   High    Low  Close   Volume    Change
# Date
# 2023-01-02  75100  76700  75000  75700  1376985  0.009333
# 2023-01-03  75600  76300  73100  75600  2719437 -0.001321
# 2023-01-04  75400  81900  75200  81000  5154609  0.071429
# 2023-01-05  83300  83300  80800  81400  3510964  0.004938
# 2023-01-06  81400  83600  81100  83100  3687430  0.020885
# 2023-01-09  84900  86000  83500  86000  3948670  0.034898
# 2023-01-10  85500  87200  85000  86500  3105311  0.005814
# 2023-01-11  87800  88400  86500  87300  3083961  0.009249
# 2023-01-12  88100  88100  85800  86800  3065582 -0.005727
# 2023-01-13  86800  87500  85400  85700  2058890 -0.012673
# 2023-01-16  86000  86500  84900  85800  1512876  0.001167
# 2023-01-17  86400  87200  85700  86000  1586136  0.002331
# 2023-01-18  86400  86500  84500  85100  1494262 -0.010465
# 2023-01-19  84000  85800  84000  85500  1674834  0.004700
# 2023-01-20  86300  87800  86100  87600  2386074  0.024561
# ...

# %%
from matplotlib import pyplot as plt
import seaborn as sns

# %%
df_ss.plot(y='Close',  marker='o', markersize=5, figsize=(10,6))

# %% [markdown]
# 큰 하락폭을 보인 1월 18일 삼성전자는 신제품 및 상승한 매출을 소개하며 기업 자체에는 긍정 이미지를 보임.

# %%
new = pd.concat([df_ss['Close'],df_sh['Close']], axis=1)
new
# Out:
#             Close  Close
# Date
# 2023-01-02  55500  75700
# 2023-01-03  55400  75600
# 2023-01-04  57800  81000
# 2023-01-05  58200  81400
# 2023-01-06  59000  83100
# 2023-01-09  60700  86000
# 2023-01-10  60400  86500
# 2023-01-11  60500  87300
# 2023-01-12  60500  86800
# 2023-01-13  60800  85700
# 2023-01-16  61100  85800
# 2023-01-17  61000  86000
# 2023-01-18  60400  85100
# 2023-01-19  61500  85500
# 2023-01-20  61800  87600
# 2023-01-25  63400  91400
# 2023-01-26  63900  92300
# 2023-01-27  64600  91500

# %%
new.plot(marker='o', markersize=5, figsize=(10,8))

# %%
df_krx.drop(df_krx.index[3:2694], inplace=True)
df_krx.drop(df_krx.index[1:2], inplace=True)
df_krx
# Out:
#      Code        ISU_CD    Name Market Dept  Close ChangeCode  Changes  \
# 0  005930  KR7005930003    삼성전자  KOSPI       64600          1      700
# 2  000660  KR7000660001  SK하이닉스  KOSPI       91500          2     -800
#
#    ChagesRatio   Open   High    Low    Volume         Amount           Marcap  \
# 0         1.10  64400  65000  63900  18760182  1212764792491  385647952730000
# 2        -0.87  91300  92800  90300   2553811   234318676392   66612216397500
#
#        Stocks MarketId
# 0  5969782550      STK
# 2   728002365      STK

# %%
import matplotlib.gridspec as gridspec
grid = gridspec.GridSpec(2,2)#그래프를 그릴 도화지 개수
  
plt.subplots_adjust(wspace= 0.4, hspace=0.3)

#서버플롯 그리기
## sns countplot으로 그래프 그리기 ( x에 대한 카운트를 그래프로 그리고 범례도 설정할 수 있다)

ss_features = ['Open','Close','High','Low']

for idx, feature in enumerate(ss_features):
    ax = plt.subplot(grid[idx])
    
    sns.countplot(x=feature,
                 data= df_ss,
                 palette = 'pastel',
                 ax= ax)

    ax.set_title(f'{feature} Distribution')
