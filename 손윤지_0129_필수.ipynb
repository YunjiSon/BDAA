# %% [markdown]
# <a href="https://colab.research.google.com/github/YunjiSon/BDAA/blob/main/%EC%86%90%EC%9C%A4%EC%A7%80_0129_%ED%95%84%EC%88%98.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
filename = ('/content/drive/MyDrive/[5기] 데이터 분석 기초반/데이터셋/bank.csv')

# %%
bank = pd.read_csv('/content/drive/MyDrive/[5기] 데이터 분석 기초반/데이터셋/bank.csv', sep=';')

# %%
filename = ('/content/drive/MyDrive/[5기] 데이터 분석 기초반/데이터셋/bank-additional.csv')

# %%
bank_new = pd.read_csv('/content/drive/MyDrive/[5기] 데이터 분석 기초반/데이터셋/bank-additional.csv', sep=';')

# %%
bank
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %%
bank_new
# Out:
#       age          job  marital          education default  housing     loan  \
# 0      30  blue-collar  married           basic.9y      no      yes       no
# 1      39     services   single        high.school      no       no       no
# 2      25     services  married        high.school      no      yes       no
# 3      38     services  married           basic.9y      no  unknown  unknown
# 4      47       admin.  married  university.degree      no      yes       no
# ...   ...          ...      ...                ...     ...      ...      ...
# 4114   30       admin.  married           basic.6y      no      yes      yes
# 4115   39       admin.  married        high.school      no      yes       no
# 4116   27      student   single        high.school      no       no       no
# 4117   58       admin.  married        high.school      no       no       no
# 4118   34   management   single        high.school      no      yes       no
#
# ...

# %%
pd.concat([bank,bank_new], axis=0)
# Out:
#       age          job  marital    education default  balance housing loan  \
# 0      30   unemployed  married      primary      no   1787.0      no   no
# 1      33     services  married    secondary      no   4789.0     yes  yes
# 2      35   management   single     tertiary      no   1350.0     yes   no
# 3      30   management  married     tertiary      no   1476.0     yes  yes
# 4      59  blue-collar  married    secondary      no      0.0     yes   no
# ...   ...          ...      ...          ...     ...      ...     ...  ...
# 4114   30       admin.  married     basic.6y      no      NaN     yes  yes
# 4115   39       admin.  married  high.school      no      NaN     yes   no
# 4116   27      student   single  high.school      no      NaN      no   no
# 4117   58       admin.  married  high.school      no      NaN      no   no
# 4118   34   management   single  high.school      no      NaN     yes   no
#
# ...

# %%
pd.concat([bank,bank_new], axis=1)
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %%
pd.concat([bank,bank_new], axis=0, ignore_index=True)
# Out:
#       age          job  marital    education default  balance housing loan  \
# 0      30   unemployed  married      primary      no   1787.0      no   no
# 1      33     services  married    secondary      no   4789.0     yes  yes
# 2      35   management   single     tertiary      no   1350.0     yes   no
# 3      30   management  married     tertiary      no   1476.0     yes  yes
# 4      59  blue-collar  married    secondary      no      0.0     yes   no
# ...   ...          ...      ...          ...     ...      ...     ...  ...
# 8635   30       admin.  married     basic.6y      no      NaN     yes  yes
# 8636   39       admin.  married  high.school      no      NaN     yes   no
# 8637   27      student   single  high.school      no      NaN      no   no
# 8638   58       admin.  married  high.school      no      NaN      no   no
# 8639   34   management   single  high.school      no      NaN     yes   no
#
# ...

# %%
pd.merge(bank,bank_new, on='job', how='inner')
# Out:
#          age_x         job marital_x education_x default_x  balance housing_x  \
# 0           30  unemployed   married     primary        no     1787        no
# 1           30  unemployed   married     primary        no     1787        no
# 2           30  unemployed   married     primary        no     1787        no
# 3           30  unemployed   married     primary        no     1787        no
# 4           30  unemployed   married     primary        no     1787        no
# ...        ...         ...       ...         ...       ...      ...       ...
# 2455559     45     unknown   married     primary        no       44        no
# 2455560     45     unknown   married     primary        no       44        no
# 2455561     45     unknown   married     primary        no       44        no
# 2455562     45     unknown   married     primary        no       44        no
# 2455563     45     unknown   married     primary        no       44        no
#
# ...

# %%
pd.merge(bank,bank_new, on='age', how='right')
# Out:
#         age       job_x marital_x education_x default_x  balance housing_x  \
# 0        30  unemployed   married     primary        no   1787.0        no
# 1        30  management   married    tertiary        no   1476.0       yes
# 2        30      admin.    single    tertiary        no    261.0        no
# 3        30    services   married   secondary        no   1808.0       yes
# 4        30  management    single    tertiary        no   1372.0        no
# ...     ...         ...       ...         ...       ...      ...       ...
# 543453   34  management    single    tertiary        no   -292.0       yes
# 543454   34  management   married    tertiary        no    436.0        no
# 543455   34  management    single    tertiary        no   2679.0       yes
# 543456   34  management   married    tertiary        no   1557.0       yes
# 543457   34  management   married    tertiary        no    297.0       yes
#
# ...

# %%
pd.merge(bank,bank_new, on='job', how='outer')
# Out:
#          age_x         job marital_x education_x default_x  balance housing_x  \
# 0           30  unemployed   married     primary        no     1787        no
# 1           30  unemployed   married     primary        no     1787        no
# 2           30  unemployed   married     primary        no     1787        no
# 3           30  unemployed   married     primary        no     1787        no
# 4           30  unemployed   married     primary        no     1787        no
# ...        ...         ...       ...         ...       ...      ...       ...
# 2455559     45     unknown   married     primary        no       44        no
# 2455560     45     unknown   married     primary        no       44        no
# 2455561     45     unknown   married     primary        no       44        no
# 2455562     45     unknown   married     primary        no       44        no
# 2455563     45     unknown   married     primary        no       44        no
#
# ...

# %%
pd.merge(bank,bank_new, on='job', how='left')
# Out:
#          age_x           job marital_x education_x default_x  balance  \
# 0           30    unemployed   married     primary        no     1787
# 1           30    unemployed   married     primary        no     1787
# 2           30    unemployed   married     primary        no     1787
# 3           30    unemployed   married     primary        no     1787
# 4           30    unemployed   married     primary        no     1787
# ...        ...           ...       ...         ...       ...      ...
# 2455559     44  entrepreneur    single    tertiary        no     1136
# 2455560     44  entrepreneur    single    tertiary        no     1136
# 2455561     44  entrepreneur    single    tertiary        no     1136
# 2455562     44  entrepreneur    single    tertiary        no     1136
# 2455563     44  entrepreneur    single    tertiary        no     1136
#
#         housing_x loan_x contact_x  day  ... campaign_y  pdays_y  previous_y  \
# ...
